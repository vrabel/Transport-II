# %% [markdown]
# ## Homework 3
# Problem 2 part g
# Maura Vrabel
# 2/7/17

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
# define parameters
c10 = 1 # M
l = 1 # cm

def lowDa(z):
    Da = 0.01
    return c10*(1-z/l)

def Da(z,Da):
    Da = 5
    return c10*((1-(np.exp(np.sqrt(Da))/(2*np.sinh(np.sqrt(Da)))))*np.exp(np.sqrt(Da))*z/l+
                (np.exp(np.sqrt(Da)*(1-z/l)))/(2*np.sinh(np.sqrt(Da))))

def highDa(z):
    Da = 100
    delta = 0.01*l
    return c10*np.exp(-np.sqrt(Da)*z)

# %%
z = np.linspace(0,l,1000)

plt.plot(z,lowDa(z))
plt.plot(z,Da(z,5))
plt.plot(z,highDa(z))
plt.title('Concentration Profile at Varying $Da_{II}$')
plt.legend(['$Da_{II}$ = 0.01','$Da_{II}$ = 5','$Da_{II}$ = 100'])
plt.xlabel('Distance (cm)')
plt.ylabel('Concentration (M)')

# %%
z = np.linspace(0,1,1000)

def Dainteractive(Da):
    Conc = c10*((1-(np.exp(np.sqrt(Da))/(2*np.sinh(np.sqrt(Da)))))*np.exp(np.sqrt(Da))*z/l+
                (np.exp(np.sqrt(Da)*(1-z/l)))/(2*np.sinh(np.sqrt(Da))))
    plt.plot(z,Conc)
    plt.title('Concentration Profile at Varying $Da_{II}$')
    plt.xlabel('Distance (cm)')
    plt.ylabel('Concentration (M)')
    
from ipywidgets import interact
interact(Da, Da=(0,100,100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-a1c6c1fa03da> in <module>()
#      10
#      11 from ipywidgets import interact
# ---> 12 interact(Da, Da=(0,100,100))
#
# C:\Users\mvrabel.2014\Anaconda3\lib\site-packages\ipywidgets\widgets\interaction.py in interact(__interact_f, **kwargs)
#     356         #        ...
#     357         f = __interact_f
# --> 358         w = interactive(f, **kwargs)
#     359         try:
#     360             f.widget = w
#
# C:\Users\mvrabel.2014\Anaconda3\lib\site-packages\ipywidgets\widgets\interaction.py in interactive(__interact_f, **kwargs)
#     222     kwargs = kwargs.copy()
#     223
# --> 224     new_kwargs = _find_abbreviations(f, kwargs)
#     225     # Before we proceed, let's make sure that the user has passed a set of args+kwargs
# ...
